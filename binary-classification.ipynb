# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer

hotel = pd.read_csv('D:\\My files\\projects\\Python\\kaggle-deep-learning-intro\\hotel.csv')

X = hotel.copy()
y = X.pop('is_canceled')

# %%
X['arrival_date_month'] = \
    X['arrival_date_month'].map(
        {'January':1, 'February': 2, 'March':3,
         'April':4, 'May':5, 'June':6, 'July':7,
         'August':8, 'September':9, 'October':10,
         'November':11, 'December':12}
    )

# %%
features_num = [
    "lead_time", "arrival_date_week_number",
    "arrival_date_day_of_month", "stays_in_weekend_nights",
    "stays_in_week_nights", "adults", "children", "babies",
    "is_repeated_guest", "previous_cancellations",
    "previous_bookings_not_canceled", "required_car_parking_spaces",
    "total_of_special_requests", "adr",
]

features_cat = [
    "hotel", "arrival_date_month", "meal",
    "market_segment", "distribution_channel",
    "reserved_room_type", "deposit_type", "customer_type",
]

# %%
transformer_num = make_pipeline(
    SimpleImputer(strategy="constant"), # there are a few missing values
    StandardScaler(),
)
transformer_cat = make_pipeline(
    SimpleImputer(strategy="constant", fill_value="NA"),
    OneHotEncoder(handle_unknown='ignore'),
)

# %%
preprocessor = make_column_transformer(
    (transformer_num, features_num),
    (transformer_cat, features_cat),
)

# %%
# stratify - make sure classes are evenly represented across splits
X_train, X_valid, y_train, y_valid = \
    train_test_split(X, y, stratify=y, train_size=0.75)

X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)

# %%
input_shape = [X_train.shape[1]]

# %%
input_shape
# Out:
# [63]

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    layers.BatchNormalization(input_shape=input_shape),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(1, activation='sigmoid')
])
# Out:
# WARNING:tensorflow:From c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['binary_accuracy']
)
# Out:
# WARNING:tensorflow:From c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=5,
    min_delta=0.001,
    restore_best_weights=True,
)

# %%
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=200,
    callbacks=[early_stopping],
)
# Out:
# Epoch 1/200
# WARNING:tensorflow:From c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 175/175 [==============================] - 4s 10ms/step - loss: 0.4789 - binary_accuracy: 0.7729 - val_loss: 0.4357 - val_binary_accuracy: 0.8032
# Epoch 2/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.4234 - binary_accuracy: 0.8011 - val_loss: 0.4017 - val_binary_accuracy: 0.8131
# Epoch 3/200
# 175/175 [==============================] - 2s 9ms/step - loss: 0.4105 - binary_accuracy: 0.8078 - val_loss: 0.3930 - val_binary_accuracy: 0.8161
# Epoch 4/200
# 175/175 [==============================] - 2s 9ms/step - loss: 0.4017 - binary_accuracy: 0.8118 - val_loss: 0.3900 - val_binary_accuracy: 0.8176
# Epoch 5/200
# 175/175 [==============================] - 2s 9ms/step - loss: 0.3975 - binary_accuracy: 0.8142 - val_loss: 0.3863 - val_binary_accuracy: 0.8196
# Epoch 6/200
# 175/175 [==============================] - 2s 9ms/step - loss: 0.3925 - binary_accuracy: 0.8172 - val_loss: 0.3831 - val_binary_accuracy: 0.8237
# Epoch 7/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3891 - binary_accuracy: 0.8198 - val_loss: 0.3805 - val_binary_accuracy: 0.8258
# Epoch 8/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3853 - binary_accuracy: 0.8209 - val_loss: 0.3781 - val_binary_accuracy: 0.8268
# Epoch 9/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3820 - binary_accuracy: 0.8227 - val_loss: 0.3735 - val_binary_accuracy: 0.8273
# Epoch 10/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3786 - binary_accuracy: 0.8253 - val_loss: 0.3724 - val_binary_accuracy: 0.8296
# Epoch 11/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3757 - binary_accuracy: 0.8267 - val_loss: 0.3686 - val_binary_accuracy: 0.8299
# Epoch 12/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3733 - binary_accuracy: 0.8280 - val_loss: 0.3711 - val_binary_accuracy: 0.8282
# Epoch 13/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3709 - binary_accuracy: 0.8299 - val_loss: 0.3667 - val_binary_accuracy: 0.8328
# Epoch 14/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3681 - binary_accuracy: 0.8300 - val_loss: 0.3641 - val_binary_accuracy: 0.8321
# Epoch 15/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3673 - binary_accuracy: 0.8307 - val_loss: 0.3686 - val_binary_accuracy: 0.8302
# Epoch 16/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3662 - binary_accuracy: 0.8305 - val_loss: 0.3657 - val_binary_accuracy: 0.8311
# Epoch 17/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3633 - binary_accuracy: 0.8336 - val_loss: 0.3601 - val_binary_accuracy: 0.8337
# Epoch 18/200
# 175/175 [==============================] - 2s 9ms/step - loss: 0.3611 - binary_accuracy: 0.8330 - val_loss: 0.3646 - val_binary_accuracy: 0.8347
# Epoch 19/200
# 175/175 [==============================] - 2s 9ms/step - loss: 0.3596 - binary_accuracy: 0.8338 - val_loss: 0.3610 - val_binary_accuracy: 0.8328
# Epoch 20/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3592 - binary_accuracy: 0.8349 - val_loss: 0.3618 - val_binary_accuracy: 0.8346
# Epoch 21/200
# 175/175 [==============================] - 2s 9ms/step - loss: 0.3570 - binary_accuracy: 0.8351 - val_loss: 0.3590 - val_binary_accuracy: 0.8343
# Epoch 22/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3561 - binary_accuracy: 0.8369 - val_loss: 0.3615 - val_binary_accuracy: 0.8349
# Epoch 23/200
# 175/175 [==============================] - 2s 9ms/step - loss: 0.3542 - binary_accuracy: 0.8371 - val_loss: 0.3582 - val_binary_accuracy: 0.8374
# Epoch 24/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3528 - binary_accuracy: 0.8374 - val_loss: 0.3585 - val_binary_accuracy: 0.8349
# Epoch 25/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3536 - binary_accuracy: 0.8366 - val_loss: 0.3555 - val_binary_accuracy: 0.8368
# Epoch 26/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3511 - binary_accuracy: 0.8392 - val_loss: 0.3563 - val_binary_accuracy: 0.8358
# Epoch 27/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3492 - binary_accuracy: 0.8390 - val_loss: 0.3564 - val_binary_accuracy: 0.8376
# Epoch 28/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3487 - binary_accuracy: 0.8394 - val_loss: 0.3578 - val_binary_accuracy: 0.8365
# Epoch 29/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3478 - binary_accuracy: 0.8392 - val_loss: 0.3565 - val_binary_accuracy: 0.8366
# Epoch 30/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3472 - binary_accuracy: 0.8397 - val_loss: 0.3550 - val_binary_accuracy: 0.8382

# %%
history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot(title="Cross-entropy")
history_df.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot(title="Accuracy")
# Out:
# <Axes: title={'center': 'Accuracy'}>
